# %% [markdown]
# <center>
# <img src="files/images/pmat.png" style="width: 400px; height: 200px; margin-left: 25%;margin-right: auto"; alt="">
# </center>

# %% [markdown]
# <center><h1>GETTING STARTED</h1></center>

# %% [markdown]
# > This notebook provides an **INTRODUCTION** to the Plotly Matlab API. Installation and Matlab / Plotly preliminaries are discussed. If you are comfortable with the basics, feel free to skip to the other notebooks and return to this one for reference.

# %% [markdown]
# <center>
#
# <a href = ./welcome_home.ipynb/#toc class="nounderline"> TABLE OF CONTENTS </a>&nbsp; &nbsp; **  •   ** &nbsp; &nbsp;<a href="#install" class="nounderline"> DOWNLOAD/STARTUP</a> &nbsp; &nbsp; **  •   ** &nbsp; &nbsp;<a href="#doc" class="nounderline"> DOCUMENTATION </a>
#
# </center>
#
# <br>
# <br>
# <br>

# %% [markdown]
# <hr size="5px">
# <h5 id="install">DOWNLOAD/STARTUP</h5>
# <hr size="5px">
#
# <br>
# <h6>DOWNLOAD:</h6>
#
# The latest Plotly Matlab API can be <a href="https://github.com/plotly/MATLAB-api/archive/master.zip" class="nounderline"><font size="4" color = "red">DOWNLOADED HERE</font></a>. Simply uncompress the zipped folder and place it in your favourite directory. The API is compatible with all modern MATLAB releases. If you have any issues with the installation please <a href = "contact" class = "nounderline">CONTACT</a> us and let us know.
# <br>

# %% [markdown]
# <h6>START UP:</h6>
#
# Throughout this notebook we will be using the awesome <a href="https://pypi.python.org/pypi/pymatbridge/0.1/" class="nounderline">pymatbridge</a> package to communicate with MATLAB from Python. Everything that comes below the **%%matlab** decorator will now be read as MATLAB code! To use the MATLAB API on your own machine, simply open the MATLAB application as you normally would.
# <br>

# %% [markdown]
# #### >> OPEN YOUR MATLAB ENVIRONMENT

# %%
# %load_ext pymatbridge
# Out:
# The pymatbridge extension is already loaded. To reload it, use:
#   %reload_ext pymatbridge

# %% [markdown]
# <br>
# <h6>SIGN UP:</h6>
#
# If you are already signed up with Plotly, skip ahead. If not - no worries! You can either sign up for a **FREE** Plotly account <a href="http://www.plot.ly" class="nounderline">ONLINE</a> *or* from the comfort of your Matlab command window using the **signup.m** function. Just copy and uncomment the lines in the code below (under the **%%matlab** decorator) into your Matlab command window. You'll also need to provide a username of your choice and valid email address!

# %% [markdown]
# #### >> SIGN UP WITH PLOTLY!

# %%
# %%matlab
#
# %username = PICK_A_USERNAME;
# %email = VALID_EMAIL_ADDRESS;
# %response = signup(username,email)

# %% [markdown]
# <br>
# <h6>SET UP:</h6>
#
# Once you are signed up with Plotly, you can setup up the Plotly MATLAB API with the newly added **plotlysetup.m** function. This function takes your username and API key as input and embeds the Plotly API into your MATLAB toolboxes folder and permanently saves your username and API key into a configuraiton file within a plotly folder located in your directory. Your MATLAB API key can be located <a href="http://www.plot.ly" class="nounderline">ONLINE</a> by *signing in* and clicking on the *settings* tab located under your username in the right hand corner of the browser.

# %% [markdown]
# #### >> SETUP THE PLOTLY API

# %%
# %%matlab
#
#  plotlysetup('matlab_user_guide','7jd7qa2s10');
# Out:
# Adding Plotly to MATLAB toolbox directory ... Done
# Saving Plotly to MATLAB search path via startup.m ...  Done
# Saving user credentials ... Done
#
# Welcome to Plotly! If you are new to Plotly please enter: >>plotlyhelp to get started!

# %% [markdown]
# Now everytime you open MATLAB, the Plotly API will be automatically added to the searchpath and you will be automatically signed in and ready to start plotting!
# <hr size ="3px">

# %% [markdown]
# <br>
# <br>
# <br>
#
# <hr size="5px">
# <h5 id="doc">DOCUMENTATION</h5>
#
# <hr size="5px">
#
# <div class = "col1">
# <h6>SETUP FUNCTIONS</h6>
#
# <h4><a href="#ps" class="nounderlineblack"> >> plotlysetup.m </a></h4>
#
# <h4><a href="#su" class="nounderlineblack"> >> signup.m </a> </h4>
#
# <h4><a href="#si" class="nounderlineblack"> >> signin.m </a></h4>
#
# <h4><a href="#spc" class="nounderlineblack"> >> saveplotlycredentials.m </a></h4>
#
# </div>
#
# <div class = "col3">
# <h6>HELP FUNCTIONS</h6>
#
# <h4><a href="#ph" class="nounderlineblack"> >> plotlyhelp.m </a></h4>
# </div>
#
# <div class = "col2">
# <h6>PLOT FUNCTIONS</h6>
#
# <h4><a href = #pl class="nounderlineblack"> >> plotly.m </a></h4>
#
# <h4><a href="#f2p" class="nounderlineblack"> >> fig2plotly.m</a></h4>
#
# <h4><a href="#gpf" class="nounderlineblack"> >> getplotlyfig.m </a></h4>
#
# <h4><a href="#spf" class = "nounderlineblack"> >> saveplotlyfig.m </a></h4>
# </div>
#
# <hr size="3px">
#
# <font size = "2px"> **NOTE:** required **data type** provded in square brackets and **defaults** provided in curly braces.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <center>
# <h2 id=ps>>> plotlysetup.m</h2>
# </center>
#
# ----
# <center>
# <h3>Setup the Plotly MATLAB API</h3>
# </center>
#
# ---
#
# The **plotlysetup.m** function removes the need to have to add the Plotly MATLAB API to your search path everytime a new MATLAB session is started. It also automatically saves your *user_name*, *api_key*, and *endpoint_domain (optional)*, removing the need to sign in everytime a new MATLAB session is started.
#
# <hr size ="3px">
#
# **<h4>[INPUT]:</h4>**
#
# <h4> >> plotlysetup(<font color="purple">'user_name'</font>,<font color="purple">'api_key'</font>) </h4>
# <h4> >> plotlysetup(<font color="purple">'user_name'</font>,<font color="purple">'api_key'</font>,end_domain)</h4>
#
#  <br>
#  **<h4>[WHERE]:</h4>**
#
#  <h4> username - your user_name [string] </h4>
#  <h4> api_key - your api_key [string]</h4>
#  <h4> end_domain - enpoint domain name [struct]{end_domain.plotly_rest_url = https://plot.ly }</h4>
#  <br>
#
#
# <hr size ="3px">
#
# The Plotly MATLAB API is saved in the MATLAB root toolbox directory. If the Plotly MATLAB API already exists in the toolbox directory, the user is prompted for overwrite. The MATLAB root directory *startup.m* script is modified to add the Plotly MATLAB API toolbox path to the MATLAB search path everytime a new session is started. The **plotlysetup.m** function calls the <a href="#spc" class="nounderlineblack"> saveplotlycredentials.m </a> function and the <a href="#si" class="nounderlineblack"> **signin.m** </a> function.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <center>
# <h2 id=su>>> signup.m</h2>
# </center>
#
# ----
# <center>
# <h3>Signup for a free Plotly Account</h3>
# </center>
#
# ---
#
# The **signup.m** function creates a Plotly account and returns a temporary password and an api_key. This process can also be completed <a href="http://www.plot.ly" class="nounderline">ONLINE</a>.
#
#
# <hr size ="3px">
#
# **<h4>[INPUT]:</h4>**
#
# <h4> >> resp = signup(<font color = "purple">'username'</font>,<font color = "purple">'e-mail'</font>) </h4>
#  <br>
#  **<h4>[WHERE]:</h4>**
#
#  <h4> username - your new user name [string] </h4>
#  <h4> api_key - your valid email address [string]</h4>
#  <br>
#
#  **<h4>[OUTPUT]:</h4>**
#
# <h4> resp - results info of the signup [struct]</h4>
# <h4>resp.[api_key,message,un,temp_pw,error] </h4>
#  <br>
#
#  **<h4>[WHERE]:</h4>**
#
#  <h4> resp.api_key - your new api key [string] </h4>
#  <h4> resp.message - greeting message [string]</h4>
#  <h4> resp.un - chosen username  [string]</h4>
#  <h4> resp.temp_pw - your temporary password [string]</h4>
#  <h4> resp.error - potential error messages [string]</h4>
#  <br>
#
# <hr size ="3px">

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <center>
# <h2 id=si>>> signin.m</h2>
# </center>
#
# ----
# <center>
# <h3>Sign in to your Plotly Account</h3>
# </center>
#
# ---
#
# The **signin.m** function can be used to specify your *user_name*, *api_key*, and *endpoint_domain* (optional) for a single MATLAB session.
#
# <hr size ="3px">
#
# **<h4>[INPUT]:</h4>**
#
# <h4> >> [un key domain] = signup(<font color="purple">'user_name'</font>,<font color="purple">'api_key'</font>) </h4>
# <h4> >> [un key domain] = signup(<font color="purple">'user_name'</font>,<font color="purple">'api_key'</font>,end_domain)</h4>
#  <br>
#  **<h4>[WHERE]:</h4>**
#
#  <h4> username - your user_name [string] </h4>
#  <h4> api_key - your api_key [string]</h4>
#  <h4> end_domain - enpoint domain name [struct]{end_domain.plotly_rest_url = https://plot.ly }</h4>
#  <br>
#
#  **<h4>[OUTPUT]:</h4>**
#
# <h4> un - your user_name [string]</h4>
# <h4> key - your api_key [string] </h4>
# <h4> domain - your endpoint domain [struct]{end_domain.plotly_rest_url = https://plot.ly }</h4>
#
# <hr size ="3px">

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <center>
# <h2 id=spc>>> saveplotlycredentials.m</h2>
# </center>
#
# ----
# <center>
# <h3>Save your Plotly credentials accross MATLAB sessions</h3>
# </center>
#
# ---
#
# The **saveplotlycredentials.m** function create stores your user information (*username*, *api_key*, and *endpoint_domain*) in a credentials file for future reference across MATLAB sessions.
#
# <hr size ="3px">
#
# **<h4>[INPUT]:</h4>**
#
# <h4> >> saveplotlycredentials(<font color="purple">'user_name'</font>,<font color="purple">'api_key'</font>) </h4>
# <h4> >> saveplotlycredentials(<font color="purple">'user_name'</font>,<font color="purple">'api_key'</font>,end_domain)</h4>
#  <br>
#  **<h4>[WHERE]:</h4>**
#
#  <h4> username - your user_name [string] </h4>
#  <h4> api_key - your api_key [string]</h4>
#  <h4> end_domain - enpoint domain name [struct]{end_domain.plotly_rest_url = https://plot.ly }</h4>
#  <br>
# <hr size ="3px">

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <center>
# <h2 id=ph>>> plotlyhelp.m</h2>
# </center>
#
# ----
# <center>
# <h3>Plotly Declarative Syntax Reference</h3>
# </center>
#
# ---
#
# **<font color = red>\*NEW\*</font>** to the Plotly MATLAB API is the **plotlyhelp.m** function, which stores all the essential Plotly data/style/layout declarative syntax references in a nested structure array. Information regarding the Plotly declaritive syntax can be accessed by passing valid fieldnames as input to **plotlyhelp.m** in the order in which they are nested.
#
# <hr size ="3px">
#
# **<h4>[INPUT]:</h4>**
#
#  <h4> >> plotlyhelp(varargin)</h4>
#  <h4> >> plotlyref = plotlyhelp(varargin)</h4>
#  <br>
#  **<h4>[WHERE]:</h4>**
#
#  <h4> varargin - comma separated variable [string] arguments. </h4>
#  <br>
#
#  **<h4>[OUTPUT]:</h4>**
#
#  <h4> plotlyref - Plotly syntax reference [struct]. </h4>
#  <br>
#
# <hr size ="3px">
#
# <font size = "2px">**NOTE:** Calling >> **plotlyhelp** with no input arguments outputs the complete first-level fieldnames of valid Plotly references.The online documentaiton can be accessed directly from MATLAB using >> **plotlyhelp('online')**.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <center>
# <h2 id=pl>>> plotly.m</h2>
# </center>
#
# ----
# <center>
# <h3>Plot a MATLAB figure object with Plotly</h3>
# </center>
#
# ---
#
# The **plotly.m** function is the heart of the MATLAB API. It handles the creation of graphs in your Plotly account from MATLAB.
#
# <hr size ="3px">
#
# **<h4>[INPUT]:</h4>**
#
# <h4> >> resp = plotly(x1,y1,x2,y2,..., kwargs) </h4>
# <h4> >> resp= plotly({data1, data2, ...}, kwargs) </h4>
#
#  <br>
#  **<h4>[WHERE]:</h4>**
#
#  <h4> x1,y1,...xn,yn - data arrays [float]</h4>
#  <h4> data1, ..., datan - data/style information [struct]</h4>
#  <h4> kwargs - optional keyword arguments [struct]</h4>
#  <br>
#
#  **<h4>[KWARGS]:</h4>**
#  <h4> kwargs.layout - layout of plot [struct]</h4>
#  <h4> kwargs.fileopt - plot extension (<font color="purple">'new'</font>,<font color="purple">'overwrite'</font>,<font color="purple">'append'</font>,<font color="purple">'extend'</font>) [string] {new}</h4>
#  <h4> kwargs.traces -  array of traces to be extended [int] </h4>
#  <h4> kwargs.world_readable - public/private plot setting (<font color="purple">'true'</font>/<font color="purple">'false'</font>) [string] {true}</h4>
#  <h4> kwargs.filename - name of plot to be created [string] {<font color="purple">'untitled'</font>} </h4>
#
#  <br>
#  **<h4>[OUTPUT]:</h4>**
#
# <h4> resp - results info of the plot [struct]</h4>
#
#  <br>
#  **<h4>[WHERE]:</h4>**
#
# <h4>resp.url - address of your newly created Plotly plot [string]</h4>
# <h4>resp.warning - additional warning message [string]</h4>
# <h4>resp.message - additional generic messages [string]</h4>
# <h4>resp.filename - name of plot created [string]</h4>
# <h4>resp.error - any error messages received [string]</h4>
#
# <hr size ="3px">

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <center>
# <h2 id=f2p>fig2plotly.m</h2>
# </center>
#
# ----
# <center>
# <h3>Plot a MATLAB figure object with Plotly</h3>
# </center>
#
# ---
#
# **<font color = red>\*NEW\*</font>** to the Plotly MATLAB API is the **fig2plotly.m** function - the future of the MATLAB API. **fig2plotly.m** allows you to take your MATLAB generated figures and automatically create a Plotly plot, taking care of the conversion from the MATLAB figure object structure to Plotly syntax.
#
# <hr size ="3px">
#
# **<h4>[INPUT]:</h4>**
#
#  <h4> >> resp = fig2plotly() </h4>
#  <h4> >> resp = fig2plotly(f)</h4>
#  <h4> >> resp = fig2plotly(gcf)</h4>
#  <h4> >> resp = fig2plotly(f,<font color = "purple">'property'</font>,value, ... )</h4>
#  <h4> >> resp = fig2plotly(gcf,<font color = "purple">'property'</font>,value, ... )</h4>
#  <br>
#  **<h4>[WHERE]:</h4>**
#
#  <h4> gcf - root figure object handle [double]. </h4>
#  <h4> f - root figure object [struct] >> f = get(gcf) </h4>
#  <br>
# **<h4>[PROPERTIES]:</h4>**
#
# <h4>'name' - name of the plot [string][<font color="purple">'untitled'</font>]</h4>
# <h4>'strip' - use plotly default styling [boolea]{0}</h4>
# <h4>'open' - opens a browser with plot result [boolean]{1}</h4>
# <br>
#
#  **<h4>[OUTPUT]:</h4>**
#
# <h4> resp - results info of the plot [struct]</h4>
#  <br>
#  **<h4>[WHERE]:</h4>**
# <h4>resp.url - address of your newly created Plotly plot [string]</h4>
# <h4>resp.warning - additional warning message [string]</h4>
# <h4>resp.message - additional generic messages [string]</h4>
# <h4>resp.filename - name of plot created [string]</h4>
# <h4>resp.error - any error messages received [string]</h4>
# <hr size ="3px">

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <h2 id=gpf id="gpf">>> getplotlyfig.m</h2>
#
# ----
# <center>
# <h3>Get data, style, and layout from the plots stored online </h3>
# </center>
#
# ---
#
# One of Plotly's secret powers is the ability to translate between MATLAB's structure/cell array syntax and JSON. This allows a smooth transition between the your figures in MATLAB and those stored in your Plotly account. In order to grab the data, style, and layout information from your plots living online, we've introduce a **<font color = red>\*NEW\*</font>** funtion into the API: **getplotlyfig.m**. In fact, we can go one step further: **getploylyfig.m** lets you grab the data, style and layout of *anyone's* Plotly plots (as long as they are made public) - not just your own! See a graph you like online? Grab the data, style and layout and make one for yourself.
# <hr size ="3px">
#
# <h4>**[INPUT]:**</h4>
#
# <h4> >> plotlyfigure = fig2plotly(<font color = "purple">'file_owner'</font>,<font color="purple">'file_id'</font>) </h4>
# <br>
# <h4>**[WHERE]:**</h4>
#
# <h4> file_owner - user name associated with the plot [string]. </h4>
# <h4> file_id - number identifier associated with the plot [string] </h4>
# <br>
# <h4>**[OUTPUT]:**</h4>
#
# <h4> plotlyfigure - results info of the plot [struct]</h4>
# <br>
# <h4>**[WHERE]:**</h4>
# <h4> plotlyfigure.data - data information associated with the plot [cell]. </h4>
# <h4> plotlyfigure.layout - layout information associated with the plot [struct] </h4>
# <br>
# <hr size ="3px">

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <h2 id="spf">>> saveplotlyfig.m</h2>
#
# ----
# <center>
# <h3>Save your MATLAB figure as an image using Plotly  </h3>
# </center>
#
# ---
#
# The **<font color = red>\*NEW\*</font>** **saveplotlyfig.m** allows for conversion from MATLAB figures to PNG using Plotly.
#
# <hr size = "3px">
#
# <h4>**[INPUT]:**</h4>
# <h4> >> saveplotlyfig(data, layout, <font color = purple>'filename'</font>) </h4>
# <br>
# <h4>**[WHERE]:**</h4>
# <br>
# <h4> data - data/style of plot [cell] </h4>
# <h4> layout - layout of plot [struct] </h4>
# <h4> filename - name of image to be saved [string] </h4>
# <br>
# <h4>**[OUTPUT]:** </h4>
# <h4>PNG image 'filename' saved to your working directory </h4>
#
# <hr size = "3px">
#
# Currently **saveplotlyfig.m** supports the creation of PNG images and is in the process of expanding to accomodate other graphics formats.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <center><h1 id="contact">[CONTACT]</h1></center>

# %% [markdown]
# ---
# Want to help improve this user guide? Please send us your comments/questions! Feedback concerning this user guide can be directed to <font color=#1d3b84>** chuck [at] plot.ly **</font>. You can also reach and follow us online via social media outlets.<br>
#
# <div class="image-line">
#
# <div class="image-cell">
# <a href="https://twitter.com/plotlygraphs">
# <img src="files/images/twitter.png" style="width: 40px; height: 40px; margin-left: 1px; margin-right: 1px"; alt="">
# </a>
# </div>
#
# <div class="image-cell">
# <a href="https://www.facebook.com/Plotly">
# <img src="files/images/facebook.png" style="width: 40px; height: 40px; margin-left: 1px; margin-right: 1px"; alt="">
# </a>
# </div>
#
# <div class="image-cell">
# <a href= https://plus.google.com/101741663283396748386/posts>
# <img src="files/images/gplus.png" style="width: 40px; height: 40px; margin-left: 1px; margin-right: 1px"; alt="">
# </a>
# </div>
#
# <div class="image-cell">
# <a href= https://www.edmodo.com/publisher/plotly>
# <img src="files/images/ed.png" style="width: 40px; height: 40px; margin-left: 1px; margin-right: 1px"; alt="">
# </a>
# </div>
#
# </div>
# <br>
# <br>
#
# ---

# %% [markdown]
# <br>
# <h4>
# <center>
# **  •   ** <br><br>
# **  •   ** <br><br>
# **  •   ** <br><br>
# **  •   ** <br><br>
# </center>
# </h4>
# <br>

# %% [markdown]
# <center><h2>[NOTEBOOK BEAUTIFICATION]</h2></center>

# %%
# CSS styling within IPython notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("./css/style_notebook.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# @font-face {
#   font-family: "Computer Modern";
#   src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
# }
# @font-face {
#   font-family: "Computer Modern";
#   font-weight: bold;
#   src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
# }
# @font-face {
#   font-family: "Computer Modern";
#   font-style: oblique;
#   src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
# }
# @font-face {
#   font-family: "Computer Modern";
#   font-weight: bold;
#   font-style: oblique;
#   src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
# }
# div.cell{
#   width:800px;
#   margin-left:17% !important;
#   margin-right:auto;
# }
# h1 {
#   /* font-family: Computer Modern, serif; */
#   width:775px;
#   color:#1d3b84;
#   font-family: ‘Lucida Console’, Monaco, monospace;
# ...

# %% [markdown]
# <center><sup>[<a href = "http://camdavidsonpilon.github.io/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/" class="nounderline">STYLE STOLEN WITHOUT HESITATION FROM CAM DAVIDSON</a>]</sup></center>
