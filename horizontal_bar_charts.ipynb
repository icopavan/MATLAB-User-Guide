# %% [markdown]
# <h1>HORIZONTAL BAR CHART USING MATLAB + PLOTLY</h1>

# %%
# %load_ext pymatbridge
# Out:
# The pymatbridge extension is already loaded. To reload it, use:
#   %reload_ext pymatbridge

# %%
# %%matlab
#
# %bar chart data
# data =rand(1,50);
#
# %make/plot barchart of the data
# barh(data);
#
# %PLOTLY
# resp_plot = fig2plotly(gcf,'strip',1);
# resp_plot
# Out:
# resp_plot =
#
#          url: 'https://plot.ly/~matlab_user_guide/628'
#      message: [1x0 char]
#      warning: [1x0 char]
#     filename: 'untitled (137)'
#        error: [1x0 char]

# %%
from IPython.display import HTML

def show_plot(url, width=700, height=500):
    s = '<iframe height="%s" id="igraph" scrolling="no" frameborder = 0 seamless="seamless" src="%s" width="%s"></iframe>' %\
    (height, "/".join(map(str,[url, width, height])), width)
    return HTML(s)

# %%
show_plot('https://plot.ly/~matlab_user_guide/628/',1000,800)
# Out:
# <iframe height="800" id="igraph" scrolling="no" frameborder = 0 seamless="seamless" src="https://plot.ly/~matlab_user_guide/628//1000/800" width="1000"></iframe>
